# %%
## Import data
import ps_parse
import pandas as pd
import numpy as np

FILE_NAME = "ps_prices.csv"

force_refresh = False

# Check if price data is present
if not os.path.exists(FILE_NAME) or force_refresh:
    print("WARNING: PS price data not found. Building index...")
    df = ps_parse.build_price_df(FILE_NAME)
else:
    print("Loading data from disk...")
    df = pd.read_csv(FILE_NAME)

print(df)
# Out:
# Loading data from disk...
#                                                   name  price           item
# 0     Parasite Eve Greatest Hits (PlayStation 1, 1998)    NaN  Playstation 1
# 1    Tiny Tank (Sony PlayStation 1, 1998) - PS1 Vin...    NaN  Playstation 1
# 2    Sony PlayStation 1 PS1 Games U Pick Choose Com...    NaN  Playstation 1
# 3    Xenogears Greatest Hits (Sony PlayStation 1, 1...    NaN  Playstation 1
# 4    Afro Samurai PS3 Sony PlayStation 3 No Manual ...    NaN  Playstation 1
# ..                                                 ...    ...            ...
# 229  Sony Playstation 4 500 GB Black PS4 4 Games & ...  335.0  Playstation 4
# 230  Sony PlayStation Bundle 4 controllers and vari...    NaN  Playstation 4
# 231  PlayStation 4 Call of Duty: Black Ops III 3 Li...    NaN  Playstation 4
# 232  Sony PlayStation 4 Console PS4 , 1TB Slim Edit...    NaN  Playstation 4
# 233  Sony PlayStation 4 BATMAN ARKHAM KNIGHT Editio...  375.0  Playstation 4
#
# ...

# %%
import ps_calc

list_ppl = ps_calc.price_per_level(df)
df_best = ps_calc.price_per_combo(df)
# Out:
# /home/lila/git/PlaystationCalculator/ps_calc.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["levels"] = df.apply(lambda x: int(x["item"].split(" ")[1]), axis=1)
# /home/lila/git/PlaystationCalculator/ps_calc.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["levels"] = df.apply(lambda x: int(x["item"].split(" ")[1]), axis=1)

# %%
df_summary = df_best.sort_values('price')

# %%
# Plot 1
import matplotlib.pyplot as plt

plt.figure()
plot = df_summary[['combo', 'price']].plot.bar(title = "Average cost to build a playstation 5 by taping lesser playstations together", legend = False)
plot.set_xticklabels(df_summary['combo'].tolist())
plt.xlabel("Variant")
plt.ylabel("Price ($CAD)")
plt.show()

# %%
# Plot 2

plt.figure()
plot = df_summary[['combo', 'price']].plot.bar(title = "Average cost to build a playstation 5 by taping lesser playstations together", legend = False)
plot.set_xticklabels(df_summary['combo'].tolist())
plt.xlabel("Variant")
plt.ylabel("Price ($CAD)")
plt.show()
